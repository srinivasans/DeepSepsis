# %% [markdown]
# # Deep Sepsis - Machine Learning for Health Project
#
# ### Authors : Srinivasan Sivanandan, Sneha Desai, Daniel Dastoor, Angad Kalra
#
# This script runs the following RNN models for early-sepsis prediction
#
# 1. GRU
# 2. GRU-M
# 3. GRU-D
# 4. LSTM
# 5. LSTM-M
# 6. LSTM-MD

# %%
# Install Dependencies for the project
#! pip3 install -r dependencies.txt

# Run Training and Generate prediction files on Test Dataset
#!./Run-All-Cox.sh
#!./Run-GRU.sh
#!./Run-All-GRUD.sh
#!./Run_LSTM.sh

# Generate the AUC, Specificity, Sensitivity, Utility
# !python3 generate_metrics.py --experiment=GRUD
# !python3 generate_metrics.py --experiment=GRU
# !python3 generate_metrics.py --experiment=GRUM
# !python3 generate_metrics.py --experiment=LSTM
# !python3 generate_metrics.py --experiment=LSTMM
# !python3 generate_metrics.py --experiment=LSTMMD
# !python3 generate_metrics.py --experiment=COX

# %%
# Generate plots of the metrics
# %matplotlib inline
from argparse import Namespace
from generate_plots import generate_plots
args=Namespace(metrics_path='', plot_path='')
args.metrics_path='metrics'
args.plot_path = 'plots'
generate_plots(args)
# Out:
# Metric: AUC
# Model: RLR Imputation Type: mean Avg: 0.6341604783142097 Std: 0.001115441650680875
# Model: RLR Imputation Type: forward Avg: 0.6845418963160644 Std: 0.0009987522819009645
# Metric: AUC
# Model: XG Imputation Type: mean Avg: 0.49848057016782094 Std: 0.02241195202848347
# Model: XG Imputation Type: forward Avg: 0.6596625295541273 Std: 0.008373146630826942
# Metric: AUC
# Model: RF Imputation Type: mean Avg: 0.6869337147733551 Std: 0.002850382434347819
# Model: RF Imputation Type: forward Avg: 0.746445220330308 Std: 0.004281749845310474
# Metric: AUC
# Model: GRUM Imputation Type: mean Avg: 0.8214422337921865 Std: 0.0016296602372724567
# Model: GRUM Imputation Type: forward Avg: 0.8148852768994262 Std: 0.0017575675146163062
# Model: GRUM Imputation Type: grud Avg: 0.7934669444771836 Std: 0.004771744302509386
# Model: GRUM Imputation Type: dae Avg: 0.8202782031431635 Std: 0.0020331984992745743
# Metric: AUC
# ...
